# %% [markdown]
# ### Data preprocessing of CSV file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score, f1_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Data preprocessing

# %%
df = pd.read_csv('Smartphone_Usage_And_Addiction_Analysis_7500_Rows.csv')

# %%
df
# Out:
#      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 0          TXN00001  U00001   21    Male                     3.23
# 1          TXN00002  U00002   24   Other                     5.09
# 2          TXN00003  U00003   31   Other                     6.06
# 3          TXN00004  U00004   32   Other                     7.83
# 4          TXN00005  U00005   25    Male                     9.96
# ...             ...     ...  ...     ...                      ...
# 7495       TXN07496  U07496   26   Other                     9.85
# 7496       TXN07497  U07497   35    Male                     5.67
# 7497       TXN07498  U07498   22  Female                     9.99
# 7498       TXN07499  U07499   23    Male                     8.74
# 7499       TXN07500  U07500   27  Female                    10.04
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                   2.01          0.89              4.55         7.55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           7500 non-null   object
#  1   user_id                  7500 non-null   object
#  2   age                      7500 non-null   int64
#  3   gender                   7500 non-null   object
#  4   daily_screen_time_hours  7500 non-null   float64
#  5   social_media_hours       7500 non-null   float64
#  6   gaming_hours             7500 non-null   float64
#  7   work_study_hours         7500 non-null   float64
#  8   sleep_hours              7500 non-null   float64
#  9   notifications_per_day    7500 non-null   int64
#  10  app_opens_per_day        7500 non-null   int64
#  11  weekend_screen_time      7500 non-null   float64
#  12  stress_level             7500 non-null   object
#  13  academic_work_impact     7500 non-null   object
# ...

# %%
df.head(6)
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
# 5       TXN00006  U00006   26   Male                     9.32
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
# 5                4.26          0.29              3.99         6.90
#
# ...

# %%
print(np.unique(df['transaction_id']))
# Out:
# ['TXN00001' 'TXN00002' 'TXN00003' ... 'TXN07498' 'TXN07499' 'TXN07500']

# %%
print(np.unique(df['user_id']))
# Out:
# ['U00001' 'U00002' 'U00003' ... 'U07498' 'U07499' 'U07500']

# %%
print(np.unique(df['stress_level']))
# Out:
# ['High' 'Low' 'Medium']

# %%
df['stress_level'].value_counts()
# Out:
# stress_level
# High      2560
# Low       2503
# Medium    2437
# Name: count, dtype: int64

# %% [markdown]
# ### Scatterplot for screentime vs Gaming time hours

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x='daily_screen_time_hours',
    y='gaming_hours',
    hue='addiction_level',
    data=df,
    alpha=0.6
)

plt.title("Screen Time vs Gaming Hours")
plt.show()

# %%
df['addiction_level'] = df['addiction_level'].fillna(df['addiction_level'].mode()[0])

# %%
df
# Out:
#      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 0          TXN00001  U00001   21    Male                     3.23
# 1          TXN00002  U00002   24   Other                     5.09
# 2          TXN00003  U00003   31   Other                     6.06
# 3          TXN00004  U00004   32   Other                     7.83
# 4          TXN00005  U00005   25    Male                     9.96
# ...             ...     ...  ...     ...                      ...
# 7495       TXN07496  U07496   26   Other                     9.85
# 7496       TXN07497  U07497   35    Male                     5.67
# 7497       TXN07498  U07498   22  Female                     9.99
# 7498       TXN07499  U07499   23    Male                     8.74
# 7499       TXN07500  U07500   27  Female                    10.04
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                   2.01          0.89              4.55         7.55
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id             0
# user_id                    0
# age                        0
# gender                     0
# daily_screen_time_hours    0
# social_media_hours         0
# gaming_hours               0
# work_study_hours           0
# sleep_hours                0
# notifications_per_day      0
# app_opens_per_day          0
# weekend_screen_time        0
# stress_level               0
# academic_work_impact       0
# addiction_level            0
# addicted_label             0
# dtype: int64

# %%
print(np.unique(df['addiction_level']))
# Out:
# ['Mild' 'Moderate' 'Severe']

# %%
df['addiction_level'].value_counts()
# Out:
# addiction_level
# Moderate    3693
# Severe      2434
# Mild        1373
# Name: count, dtype: int64

# %%
df['stress_level'].value_counts()
# Out:
# stress_level
# High      2560
# Low       2503
# Medium    2437
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (7500, 16)

# %%
counts = [980,120,40]
addiction_level = ('Moderate','Severe','Mild')

index = np.arange(len(addiction_level))

# %%
plt.bar(index,counts,color = ['red','blue','cyan'])
plt.xlabel('addiction levels')
plt.ylabel('Frequency')
plt.title('Barplot distribution of addiction levels')
plt.xticks(index,addiction_level,rotation = 360)
plt.show()

# %%
if df["gender"].dtype == "object":
    df["gender"] = df["gender"].map({
        "Male":0,
        "Female":1,
        "Other":2
    })

# %%
if df["stress_level"].dtype == "object":
    df["stress_level"] = df["stress_level"].map({
        "High":0,
        "Low":1,
        "Medium":2
    })

# %%
if df["academic_work_impact"].dtype == "object":
    df["academic_work_impact"] = df["academic_work_impact"].map({
        "Yes":0,
        "No":1,
        
    })

# %%
if df["addiction_level"].dtype == "object":
    df["addiction_level"] = df["addiction_level"].map({
        "Moderate":0,
        "Severe":1,
        "Mild":2
        
    })

# %%
df
# Out:
#      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 0          TXN00001  U00001   21       0                     3.23
# 1          TXN00002  U00002   24       2                     5.09
# 2          TXN00003  U00003   31       2                     6.06
# 3          TXN00004  U00004   32       2                     7.83
# 4          TXN00005  U00005   25       0                     9.96
# ...             ...     ...  ...     ...                      ...
# 7495       TXN07496  U07496   26       2                     9.85
# 7496       TXN07497  U07497   35       0                     5.67
# 7497       TXN07498  U07498   22       1                     9.99
# 7498       TXN07499  U07499   23       0                     8.74
# 7499       TXN07500  U07500   27       1                    10.04
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                   2.01          0.89              4.55         7.55
# ...

# %% [markdown]
# ### Model training

# %% [markdown]
#  Feature engineering

# %%
def engineer(df):

    df = df.copy()

    df['social_media_screen_ratio'] = df['social_media_hours'] / (df['daily_screen_time_hours'] + 0.01)

    df['gaming_screen_ratio'] = df['gaming_hours'] / (df['daily_screen_time_hours'] + 0.01)

    df['pickups_per_hour'] = df['app_opens_per_day'] / 16

    df['sleep_deprivation_risk'] = (df['sleep_hours'] < 6).astype(int)

    df['high_social_media'] = (df['social_media_hours'] > 3).astype(int)

    return df


df = engineer(df)

# %% [markdown]
# Feature list

# %%
FEATURES = [
    'age',
    'gender',
    'daily_screen_time_hours',
    'social_media_hours',
    'gaming_hours',
    'work_study_hours',
    'sleep_hours',
    'notifications_per_day',
    'app_opens_per_day',
    'weekend_screen_time',
    'stress_level',
    'academic_work_impact',
    'social_media_screen_ratio',
    'gaming_screen_ratio',
    'pickups_per_hour',
    'sleep_deprivation_risk',
    'high_social_media'
]

# %%
X = df[FEATURES]
y = df["addicted_label"]

# %% [markdown]
# ### Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Model building

# %%
gbm = GradientBoostingClassifier(
    n_estimators=200,
    max_depth=4,
    learning_rate=0.05,
    random_state=42
)

rf = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42
)

et = ExtraTreesClassifier(
    n_estimators=200,
    max_depth=12,
    random_state=42
)

lr = LogisticRegression(
    max_iter=1000
)


stacking_model = StackingClassifier(

    estimators=[
        ("gbm", gbm),
        ("rf", rf),
        ("et", et)
    ],

    final_estimator=lr,
    cv=5
)

# %% [markdown]
# ### Model training

# %%
print("\nTraining Stacking Ensemble Model...\n")

stacking_model.fit(X_train_scaled, y_train)
# Out:
# Training Stacking Ensemble Model...
# StackingClassifier(cv=5,
#                    estimators=[('gbm',
#                                 GradientBoostingClassifier(learning_rate=0.05,
#                                                            max_depth=4,
#                                                            n_estimators=200,
#                                                            random_state=42)),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=10,
#                                                        n_estimators=300,
#                                                        random_state=42)),
#                                ('et',
#                                 ExtraTreesClassifier(max_depth=12,
#                                                      n_estimators=200,
#                                                      random_state=42))],
# ...

# %% [markdown]
# ### Model evaluation

# %%
y_pred = stacking_model.predict(X_test_scaled)

y_prob = stacking_model.predict_proba(X_test_scaled)[:,1]


print("\nAccuracy:", accuracy_score(y_test, y_pred))

print("\nF1 Score:", f1_score(y_test, y_pred))

print("\nROC AUC:", roc_auc_score(y_test, y_prob))


print("\nClassification Report:\n")

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9393333333333334
#
# F1 Score: 0.956769596199525
#
# ROC AUC: 0.9897561248269398
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       438
#            1       0.97      0.95      0.96      1062
#
#     accuracy                           0.94      1500
#    macro avg       0.92      0.93      0.93      1500
# weighted avg       0.94      0.94      0.94      1500

# %% [markdown]
# ### Confusion matrix of the given model

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Not Addicted","Addicted"],
    yticklabels=["Not Addicted","Addicted"]
)

plt.title("Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()

# %% [markdown]
# ### ROC Curve

# %%
fpr, tpr, _ = roc_curve(y_test, y_prob)

plt.figure(figsize=(6,5))

plt.plot(fpr, tpr, label="Stacking Model")

plt.plot([0,1],[0,1],"--")

plt.xlabel("False Positive Rate")

plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.show()

# %%
import pickle

# Save the model
with open("smartphone_addiction_model.pkl", "wb") as file:
    pickle.dump(stacking_model, file)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model',stacking_model)
])

pipeline.fit(X_train, y_train)

joblib.dump(pipeline, "addiction_pipeline.pkl")
# Out:
# ['addiction_pipeline.pkl']
